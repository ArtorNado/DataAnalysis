# %%
import pandas as pd
na_values = ['NO CLUE', 'N/A', '0']
data = pd.read_csv('C:/Users/One/Downloads/Dataset/dataframe_ORGANICS/ORGANICS.csv', na_values=na_values, delimiter=',')

# %%
columList = data.columns.tolist()
for val in columList:
    print(data[val].value_counts())
# Out:
# 919551      1
# 31263364    1
# 16061047    1
# 26897016    1
# 14705273    1
#            ..
# 36957204    1
# 15734072    1
# 24522902    1
# 34342202    1
# 48858708    1
# Name: ID, Length: 22223, dtype: int64
# 8.0     2634
# 7.0     2588
# 9.0     2584
# 6.0     2234
# 10.0    2172
# 11.0    1676
# 5.0     1662
# 12.0    1241
# 4.0      983
# 13.0     856
# 14.0     594
# 3.0      533
# 15.0     403
# 16.0     245
# 2.0      200
# 17.0     145
# 18.0      89
# 19.0      71
# 20.0      59
# 1.0       36
# 21.0      36
# 22.0      25
# 23.0      17
# 24.0      15
# 25.0      13
# 26.0       6
# 27.0       5
# 30.0       3
# 29.0       3
# 31.0       2
# 34.0       1
# 28.0       1
# Name: DemAffl, dtype: int64
# 51.0    610
# 50.0    592
# 52.0    540
# 53.0    537
# 47.0    530
#        ...
# 22.0     18
# 20.0     10
# 19.0     10
# 21.0      8
# 18.0      5
# Name: DemAge, Length: 62, dtype: int64
# 52.0    1205
# 27.0     938
# 4.0      850
# 12.0     810
# 51.0     778
# ...
