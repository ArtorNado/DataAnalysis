# %%
import pandas as pd
na_values = ['NO CLUE', 'N/A', '0']
data = pd.read_csv('C:/Users/One/Downloads/Dataset/bank-full.csv', na_values=na_values, delimiter=';')

# %%
columList = data.columns.tolist()
for val in columList:
    print(data[val].value_counts())
# Out:
# 32    2085
# 31    1996
# 33    1972
# 34    1930
# 35    1894
#       ...
# 90       2
# 92       2
# 93       2
# 95       2
# 94       1
# Name: age, Length: 77, dtype: int64
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64
# married     27214
# single      12790
# divorced     5207
# Name: marital, dtype: int64
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64
# no     44396
# yes      815
# Name: default, dtype: int64
#  1.0        195
#  2.0        156
#  4.0        139
#  3.0        134
#  5.0        113
#            ...
#  17413.0      1
#  8585.0       1
# -611.0        1
#  5889.0       1
#  7578.0       1
# ...
