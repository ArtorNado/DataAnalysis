# %%
import pandas as pd
na_values = ['NO CLUE', 'N/A', '0']
data = pd.read_csv('C:/Users/One/Downloads/Dataset/dataframe_nba_2013/nba_2013.csv', na_values=na_values, delimiter=',')

# %%
columList = data.columns.tolist()
for val in columList:
    print(data[val].value_counts())
# Out:
# Meyers Leonard      1
# JaVale McGee        1
# C.J. Miles          1
# Gorgui Dieng        1
# Jannero Pargo       1
#                    ..
# Hilton Armstrong    1
# Miles Plumlee       1
# Lavoy Allen         1
# Tobias Harris       1
# Matt Barnes         1
# Name: player, Length: 481, dtype: int64
# SG    109
# SF     99
# PF     96
# C      90
# PG     85
# G       1
# F       1
# Name: pos, dtype: int64
# 25    51
# 23    50
# 24    45
# 26    43
# 22    41
# 27    39
# 28    36
# 29    29
# 21    23
# 31    21
# 33    20
# 30    17
# 20    16
# 32    14
# 35    10
# 34     8
# 36     6
# 37     6
# 39     2
# 38     2
# 19     2
# Name: age, dtype: int64
# TOT    63
# NOP    18
# OKC    17
# LAC    16
# UTA    16
# LAL    16
# HOU    15
# MIA    15
# DET    15
# POR    15
# DAL    15
# BRK    15
# NYK    15
# PHO    15
# ATL    15
# WAS    14
# BOS    14
# MIN    14
# SAS    14
# CLE    14
# MIL    13
# CHA    13
# ORL    13
# MEM    13
# PHI    12
# GSW    12
# IND    12
# ...
