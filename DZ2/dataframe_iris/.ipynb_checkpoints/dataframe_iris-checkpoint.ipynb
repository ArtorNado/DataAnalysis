# %%
import pandas as pd
na_values = ['NO CLUE', 'N/A', '0']
data = pd.read_csv('C:/Users/One/Downloads/Dataset/dataframe_iris/iris.csv', na_values=na_values, delimiter=',')

# %%
columList = data.columns.tolist()
for val in columList:
    print(data[val].value_counts())
# Out:
# 5.0    10
# 6.3     9
# 5.1     9
# 6.7     8
# 5.7     8
# 5.5     7
# 5.8     7
# 6.4     7
# 6.0     6
# 4.9     6
# 6.1     6
# 5.4     6
# 5.6     6
# 6.5     5
# 4.8     5
# 7.7     4
# 6.9     4
# 5.2     4
# 6.2     4
# 4.6     4
# 7.2     3
# 6.8     3
# 4.4     3
# 5.9     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 4.3     1
# 7.9     1
# 7.3     1
# 7.0     1
# 4.5     1
# 5.3     1
# 7.1     1
# Name: sepal_length, dtype: int64
# 3.0    26
# 2.8    14
# 3.2    13
# 3.4    12
# 3.1    11
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.8     6
# 3.3     6
# 2.6     5
# 2.3     4
# 3.6     4
# 2.4     3
# 2.2     3
# 3.7     3
# 3.9     2
# 4.2     1
# 4.1     1
# 4.4     1
# 2.0     1
# 4.0     1
# Name: sepal_width, dtype: int64
# 1.5    13
# 1.4    13
# 5.1     8
# 4.5     8
# 1.3     7
# 1.6     7
# 5.6     6
# 4.0     5
# 4.9     5
# 4.7     5
# 4.8     4
# 1.7     4
# 4.4     4
# 4.2     4
# 5.0     4
# 4.1     3
# 5.5     3
# 4.6     3
# 6.1     3
# ...
